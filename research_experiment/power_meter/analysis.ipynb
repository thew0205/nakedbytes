# %%
import os
import subprocess
import sys
import json
import pandas as pd

# %%
run_iteration = 100
pwd = os.getcwd()
build_dir = os.path.join(pwd, "build")

# %%
def run(cmd, cwd=None) -> str:
    """Run a command and exit on failure (like set -e)."""
    print(f"+ {' '.join(cmd)}")
    result = subprocess.run(cmd, cwd=cwd, check=True, capture_output=True, text=True)
    return result.stdout

# %%
def analysis_code(key, data_tag) -> dict:
    binary_path = os.path.join(build_dir, f"power_meter_{key}")
    program_results = []
    if os.path.isfile(binary_path):
        print("\n" + "=" * 102)
        print(f"Analyzing for {key} ...")

        # Match bash loop: for i in {1..1}
        for i in range(0, run_iteration):
            if data_tag:
                data_file = os.path.join(
                    pwd, f"power_meter_{data_tag}_data.bin"
                )
                
                result = subprocess.run([binary_path, data_file], cwd=None, check=True, capture_output=True, text=True)
            else:
                result = subprocess.run([binary_path], cwd=None, check=True, capture_output=True, text=True)
            program_results.append(json.loads(result.stdout))


        # size binary
        result = run(["size", binary_path])
        lines = result.strip().splitlines()

        headers = lines[0].split()
        values = lines[1].split(maxsplit=len(headers) - 1)

        size_dict = dict(zip(headers, values))
        
        analysis_result = {"key":key,"program_results": program_results, "size_results": size_dict}
        return analysis_result

    else:
        raise ValueError(f"Error: Program {binary_path} not found!")

# %%
def analysis_deserialization(results: dict, id: str):
    rows = []

    overhead = results['overhead_deserialization']["program_results"]
    overhead_time_taken = sum(r["time_taken"] for r in overhead)/ len([r["time_taken"] for r in overhead])
    overhead_buffer_size = sum(r["buffer_size"] for r in overhead)/ len([r["buffer_size"] for r in overhead])
    overhead_flash_text = int(results['overhead_deserialization']['size_results']['text'])
    overhead_static_ram = (
                   int(results['overhead_deserialization']['size_results']["data"])
                    + int(results['overhead_deserialization']['size_results']["bss"])
                )
    for key, program in results.items():
        if id in key:
            times = [r["time_taken"] for r in program["program_results"]]
            buffers = [r["buffer_size"] for r in program["program_results"]]

            rows.append({
                "id": key,
                "avg_time_taken": sum(times) / len(times),
                "min_time": min(times),
                "max_time": max(times),
                "buffer_size": (sum(buffers) / len(buffers)),
                "flash_text": program["size_results"]["text"],
                "static_ram": (
                   int( program["size_results"]["data"])
                    + int(program["size_results"]["bss"])
                ),
                "avg_time_taken_net": (sum(times) / len(times)) - overhead_time_taken,
                "min_time_net": min(times) - overhead_time_taken,
                "max_time_net": max(times) - overhead_time_taken,
                "buffer_size_net": buffers[0] - overhead_buffer_size,
                "flash_text_net": int(program["size_results"]["text"]) - overhead_flash_text,
                "static_ram_net": (
                   int( program["size_results"]["data"])
                    + int(program["size_results"]["bss"])
                ) - overhead_static_ram,
            })

    df = pd.DataFrame(rows)
    # print(df)
    return df

# %%
def analysis_serialization(results: dict, id: str):
    rows = []

    overhead = results['overhead_serialization']["program_results"]
    overhead_time_taken = sum(r["time_taken"] for r in overhead)/ len([r["time_taken"] for r in overhead])
    overhead_buffer_size = sum(r["buffer_size"] for r in overhead)/ len([r["buffer_size"] for r in overhead])
    overhead_flash_text = int(results['overhead_serialization']['size_results']['text'])
    overhead_static_ram = (
                   int(results['overhead_serialization']['size_results']["data"])
                    + int(results['overhead_serialization']['size_results']["bss"])
                )
    for key, program in results.items():
        if id in key:
            times = [r["time_taken"] for r in program["program_results"]]
            buffers = [r["buffer_size"] for r in program["program_results"]]

            rows.append({
                "id": key,
                "avg_time_taken": sum(times) / len(times),
                "min_time": min(times),
                "max_time": max(times),
                "buffer_size": (sum(buffers) / len(buffers)),
                "flash_text": program["size_results"]["text"],
                "static_ram": (
                   int( program["size_results"]["data"])
                    + int(program["size_results"]["bss"])
                ),
                "avg_time_taken_net": (sum(times) / len(times)) - overhead_time_taken,
                "min_time_net": min(times) - overhead_time_taken,
                "max_time_net": max(times) - overhead_time_taken,
                "buffer_size_net": buffers[0] - overhead_buffer_size,
                "flash_text_net": int(program["size_results"]["text"]) - overhead_flash_text,
                "static_ram_net": (
                   int( program["size_results"]["data"])
                    + int(program["size_results"]["bss"])
                ) - overhead_static_ram,
            })

    df = pd.DataFrame(rows)
    # print(df)
    return df

# %%
program_results = {}
def main():
    # Configure and build
    run(["cmake", "-S", ".", "-B", "build"])
    run(["cmake", "--build", "build", "-j12"])

    # Program map (ordered like bash associative array is NOT guaranteed,
    # but Python 3.7+ dict preserves insertion order)
    programs = {
        "overhead_deserialization": "overhead",

        "nakedbytes_deserialization_without_access": "nakedbytes",
        "nakedbytes_deserialization_with_one_access": "nakedbytes",
        "nakedbytes_deserialization_with_all_access": "nakedbytes",

        "flatbuffers_deserialization_without_access": "flatbuffers",
        "flatbuffers_deserialization_with_one_access": "flatbuffers",
        "flatbuffers_deserialization_with_all_access": "flatbuffers",

        "protobuf_deserialization_without_access": "protobuf",
        "protobuf_deserialization_with_one_access": "protobuf",
        "protobuf_deserialization_with_all_access": "protobuf",

        "nanopb_deserialization_without_access": "protobuf",
        "nanopb_deserialization_with_one_access": "protobuf",
        "nanopb_deserialization_with_all_access": "protobuf",

        "overhead_serialization": "",

        "nakedbytes_serialization_primitives": "",
        "nakedbytes_serialization_all": "",

        "flatbuffers_serialization_primitives": "",
        "flatbuffers_serialization_all": "",

        "protobuf_serialization_primitives": "",
        "protobuf_serialization_all": "",

        "nanopb_serialization_primitives": "",
        "nanopb_serialization_all": "",
    }

    for key, data_tag in programs.items():
       program_results[key] = analysis_code(key=key, data_tag= data_tag)
    print(json.dumps(program_results,indent = 2 ))

# %%
main()
# Out:
# + cmake -S . -B build
# + cmake --build build -j12
#
# ======================================================================================================
# Analyzing for overhead_deserialization ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_overhead_deserialization
#
# ======================================================================================================
# Analyzing for nakedbytes_deserialization_without_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_without_access
#
# ======================================================================================================
# Analyzing for nakedbytes_deserialization_with_one_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_with_one_access
#
# ======================================================================================================
# Analyzing for nakedbytes_deserialization_with_all_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_with_all_access
#
# ======================================================================================================
# Analyzing for flatbuffers_deserialization_without_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_flatbuffers_deserialization_without_access
#
# ======================================================================================================
# Analyzing for flatbuffers_deserialization_with_one_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_flatbuffers_deserialization_with_one_access
#
# ======================================================================================================
# Analyzing for flatbuffers_deserialization_with_all_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_flatbuffers_deserialization_with_all_access
#
# ======================================================================================================
# Analyzing for protobuf_deserialization_without_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_protobuf_deserialization_without_access
#
# ======================================================================================================
# Analyzing for protobuf_deserialization_with_one_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_protobuf_deserialization_with_one_access
#
# ======================================================================================================
# Analyzing for protobuf_deserialization_with_all_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_protobuf_deserialization_with_all_access
#
# ======================================================================================================
# Analyzing for nanopb_deserialization_without_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_deserialization_without_access
#
# ======================================================================================================
# Analyzing for nanopb_deserialization_with_one_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_deserialization_with_one_access
#
# ======================================================================================================
# Analyzing for nanopb_deserialization_with_all_access ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_deserialization_with_all_access
#
# ======================================================================================================
# Analyzing for overhead_serialization ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_overhead_serialization
#
# ======================================================================================================
# Analyzing for nakedbytes_serialization_primitives ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_serialization_primitives
#
# ======================================================================================================
# Analyzing for nakedbytes_serialization_all ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_serialization_all
#
# ======================================================================================================
# Analyzing for flatbuffers_serialization_primitives ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_flatbuffers_serialization_primitives
#
# ======================================================================================================
# Analyzing for flatbuffers_serialization_all ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_flatbuffers_serialization_all
#
# ======================================================================================================
# Analyzing for protobuf_serialization_primitives ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_protobuf_serialization_primitives
#
# ======================================================================================================
# Analyzing for protobuf_serialization_all ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_protobuf_serialization_all
#
# ======================================================================================================
# Analyzing for nanopb_serialization_primitives ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_serialization_primitives
#
# ======================================================================================================
# Analyzing for nanopb_serialization_all ...
# + size /home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_serialization_all
# {
#   "overhead_deserialization": {
#     "key": "overhead_deserialization",
#     "program_results": [
#       {
#         "iteration": 100000,
#         "time_taken": 145,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 401,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 163,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 147,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 151,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 206,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 191,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 274,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 264,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 200,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 318,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 336,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 205,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 209,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 296,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 208,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 177,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 147,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 363,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 144,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 361,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 152,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 217,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 128,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 164,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 343,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 155,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 220,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 222,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 136,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 311,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 327,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 171,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 154,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 303,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 188,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 332,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 156,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 316,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 202,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 280,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 185,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 402,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 280,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 161,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 158,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 136,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 157,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 204,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 273,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 198,
#         "buffer_size": 0
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 217,
#         "buffer_size": 0
#       }
#     ],
#     "size_results": {
#       "text": "2781",
#       "data": "672",
#       "bss": "8",
#       "dec": "3461",
#       "hex": "d85",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_overhead_deserialization"
#     }
#   },
#   "nakedbytes_deserialization_without_access": {
#     "key": "nakedbytes_deserialization_without_access",
#     "program_results": [
#       {
#         "iteration": 100000,
#         "time_taken": 208,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 258,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 247,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 250,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 248,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 212,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 212,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 219,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 225,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 222,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 250,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 221,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 236,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 222,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 258,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 247,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 243,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 351,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 359,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 201,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 190,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 257,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 436,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 352,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 428,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 260,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 192,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 153,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 221,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 218,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 207,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 258,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 276,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 213,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 171,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 308,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 368,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 323,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 187,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 167,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 360,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 164,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 141,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 151,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 369,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 156,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 362,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 221,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 346,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 329,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 307,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 195,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 316,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 229,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 155,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 215,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 154,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 159,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 144,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 150,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 334,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 351,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       }
#     ],
#     "size_results": {
#       "text": "2781",
#       "data": "672",
#       "bss": "8",
#       "dec": "3461",
#       "hex": "d85",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_without_access"
#     }
#   },
#   "nakedbytes_deserialization_with_one_access": {
#     "key": "nakedbytes_deserialization_with_one_access",
#     "program_results": [
#       {
#         "iteration": 100000,
#         "time_taken": 140,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 161,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 151,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 230,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 156,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 153,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 167,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 177,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 167,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 350,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 379,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 185,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 160,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 402,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 163,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 258,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 159,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 162,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 164,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 301,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 286,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 216,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 136,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 229,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 192,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 297,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 159,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 178,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 402,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 164,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 243,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 170,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 146,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 157,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 198,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 158,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 128,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 143,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 140,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 157,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 231,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 244,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 345,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 313,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 252,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 329,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 365,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 132,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 133,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 248,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 165,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 151,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 174,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 294,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 135,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 292,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 139,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 217,
#         "buffer_size": 72
#       }
#     ],
#     "size_results": {
#       "text": "2823",
#       "data": "672",
#       "bss": "8",
#       "dec": "3503",
#       "hex": "daf",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_with_one_access"
#     }
#   },
#   "nakedbytes_deserialization_with_all_access": {
#     "key": "nakedbytes_deserialization_with_all_access",
#     "program_results": [
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 603,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 324,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 613,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 536,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 302,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 290,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 323,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 305,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 316,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 308,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 335,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 390,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 322,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 325,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 315,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 356,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 348,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 290,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 290,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 325,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 420,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 316,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 316,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 325,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 334,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 327,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 478,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 370,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 334,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 378,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 335,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 397,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 324,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 307,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 487,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 348,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 361,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 390,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 289,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 335,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 323,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 334,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 359,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 327,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 334,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 376,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 307,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 290,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 326,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 333,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 307,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 330,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 335,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 336,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 307,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 604,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 312,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 341,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 306,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 357,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 290,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 298,
#         "buffer_size": 72
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 325,
#         "buffer_size": 72
#       }
#     ],
#     "size_results": {
#       "text": "3173",
#       "data": "672",
#       "bss": "8",
#       "dec": "3853",
#       "hex": "f0d",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nakedbytes_deserialization_with_all_access"
#     }
#   },
# ...
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 33151,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 33136,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 41112,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32363,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 33962,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42813,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 34682,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31926,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32475,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 40305,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 35053,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32333,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 35040,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31283,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28020,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 35336,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32705,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 33775,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31387,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 29886,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 39829,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28705,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 30183,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 29795,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32691,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32479,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 29934,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 29135,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31069,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31559,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28577,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28825,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 27433,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28283,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 30738,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 27038,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 27693,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 30534,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 26959,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 31676,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 28617,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 32933,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47518,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 36797,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 48640,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49198,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 40540,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 37241,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42164,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 36761,
#         "buffer_size": 33
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 36698,
#         "buffer_size": 33
#       }
#     ],
#     "size_results": {
#       "text": "28185",
#       "data": "704",
#       "bss": "8",
#       "dec": "28897",
#       "hex": "70e1",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_serialization_primitives"
#     }
#   },
#   "nanopb_serialization_all": {
#     "key": "nanopb_serialization_all",
#     "program_results": [
#       {
#         "iteration": 100000,
#         "time_taken": 46019,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47094,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 52401,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49894,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 52099,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 46080,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 68434,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 82995,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 67202,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 87444,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 52222,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49719,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 46048,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47275,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 41749,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49374,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43592,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42455,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44229,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 48102,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 59572,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49170,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 48189,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 50076,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45191,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 51160,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 56016,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 61780,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 46547,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47809,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 54468,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45807,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 56819,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 50171,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49674,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 52495,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49101,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42918,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44262,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49449,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45734,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 41045,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 41069,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 54515,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 55333,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44073,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 40845,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 50459,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 52430,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43106,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42144,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45347,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45362,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45767,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42859,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 60977,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45771,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 51851,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 67033,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45144,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 72248,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45797,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 61667,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49381,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 59841,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 51100,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49388,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44667,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 50138,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44764,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 46107,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44328,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 57672,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 58866,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43219,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42213,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 48820,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43493,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44899,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47059,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44826,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 51060,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44134,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43114,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42638,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 41035,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 49444,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45057,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42036,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45605,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 43087,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 62365,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47616,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 50220,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44322,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 47232,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 44824,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 45223,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 55960,
#         "buffer_size": 66
#       },
#       {
#         "iteration": 100000,
#         "time_taken": 42859,
#         "buffer_size": 66
#       }
#     ],
#     "size_results": {
#       "text": "28265",
#       "data": "704",
#       "bss": "8",
#       "dec": "28977",
#       "hex": "7131",
#       "filename": "/home/busoye_tm/Documents/matthew/projects/nakedbytes/research_experiment/power_meter/build/power_meter_nanopb_serialization_all"
#     }
#   }
# }

# %%
analysis_deserialization(program_results, "deserialization_without_access")
# Out:
#                                            id  avg_time_taken  min_time  \
# 0   nakedbytes_deserialization_without_access          206.23       132
# 1  flatbuffers_deserialization_without_access          147.30       128
# 2     protobuf_deserialization_without_access        20299.78     14335
# 3       nanopb_deserialization_without_access        49609.28     42023
#
#    max_time  buffer_size flash_text  static_ram  avg_time_taken_net  \
# 0       436         72.0       2781         680               23.03
# 1       339        108.0       2781         680              -35.90
# 2     41635         66.0    2738408      154364            20116.58
# 3     75056         66.0      18390         744            49426.08
#
#    min_time_net  max_time_net  buffer_size_net  flash_text_net  static_ram_net
# 0         -51.2         252.8             72.0               0               0
# 1         -55.2         155.8            108.0               0               0
# 2       14151.8       41451.8             66.0         2735627          153684
# 3       41839.8       74872.8             66.0           15609              64

# %%
analysis_deserialization(program_results, "deserialization_with_one_access")
# Out:
#                                             id  avg_time_taken  min_time  \
# 0   nakedbytes_deserialization_with_one_access          179.77       128
# 1  flatbuffers_deserialization_with_one_access          231.93       163
# 2     protobuf_deserialization_with_one_access        16873.52     14047
# 3       nanopb_deserialization_with_one_access        51015.90     43644
#
#    max_time  buffer_size flash_text  static_ram  avg_time_taken_net  \
# 0       402         72.0       2823         680               -3.43
# 1       876        108.0       2970         680               48.73
# 2     26300         66.0    2738676      154364            16690.32
# 3     74243         66.0      18550         744            50832.70
#
#    min_time_net  max_time_net  buffer_size_net  flash_text_net  static_ram_net
# 0         -55.2         218.8             72.0              42               0
# 1         -20.2         692.8            108.0             189               0
# 2       13863.8       26116.8             66.0         2735895          153684
# 3       43460.8       74059.8             66.0           15769              64

# %%
analysis_deserialization(program_results, "deserialization_with_all_access")
# Out:
#                                             id  avg_time_taken  min_time  \
# 0   nakedbytes_deserialization_with_all_access          333.46       289
# 1  flatbuffers_deserialization_with_all_access          667.69       538
# 2     protobuf_deserialization_with_all_access        17300.92     14015
# 3       nanopb_deserialization_with_all_access        50507.97     43765
#
#    max_time  buffer_size flash_text  static_ram  avg_time_taken_net  \
# 0       613         72.0       3173         680              150.26
# 1      1522        108.0       3549         680              484.49
# 2     35185         66.0    2738840      154364            17117.72
# 3     71665         66.0      18742         744            50324.77
#
#    min_time_net  max_time_net  buffer_size_net  flash_text_net  static_ram_net
# 0         105.8         429.8             72.0             392               0
# 1         354.8        1338.8            108.0             768               0
# 2       13831.8       35001.8             66.0         2736059          153684
# 3       43581.8       71481.8             66.0           15961              64

# %%
analysis_serialization(program_results, "serialization_primitive")
# Out:
#                                      id  avg_time_taken  min_time  max_time  \
# 0   nakedbytes_serialization_primitives          154.08       113       480
# 1  flatbuffers_serialization_primitives         6527.68      5703      9192
# 2     protobuf_serialization_primitives         5557.72      4971      7619
# 3       nanopb_serialization_primitives        32036.43     26104     49198
#
#    buffer_size flash_text  static_ram  avg_time_taken_net  min_time_net  \
# 0         36.0       1974         632               11.73        -29.35
# 1         56.0      23342         728             6385.33       5560.65
# 2         33.0    2738580      154356             5415.37       4828.65
# 3         33.0      28185         712            31894.08      25961.65
#
#    max_time_net  buffer_size_net  flash_text_net  static_ram_net
# 0        337.65             36.0             121               0
# 1       9049.65             56.0           21489              96
# 2       7476.65             33.0         2736727          153724
# 3      49055.65             33.0           26332              80

# %%
analysis_serialization(program_results, "serialization_all")
# Out:
#                               id  avg_time_taken  min_time  max_time  \
# 0   nakedbytes_serialization_all          137.86       122       295
# 1  flatbuffers_serialization_all         7552.28      6562     11923
# 2     protobuf_serialization_all         5538.47      4807      9376
# 3       nanopb_serialization_all        49742.89     40845     87444
#
#    buffer_size flash_text  static_ram  avg_time_taken_net  min_time_net  \
# 0         71.0       1974         632               -4.49        -20.35
# 1        108.0      23694         728             7409.93       6419.65
# 2         66.0    2738708      154356             5396.12       4664.65
# 3         66.0      28265         712            49600.54      40702.65
#
#    max_time_net  buffer_size_net  flash_text_net  static_ram_net
# 0        152.65             71.0             121               0
# 1      11780.65            108.0           21841              96
# 2       9233.65             66.0         2736855          153724
# 3      87301.65             66.0           26412              80
